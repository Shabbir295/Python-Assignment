# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
name = "Shabbir"
father_name = "Fayyaz"
date_of_birth = "24-6-2010"

# %%
print ("Name: " + name + "\nFather's Name: " + father_name + "\nDate of Birth: " + date_of_birth)
# Out:
# Name: Shabbir
# Father's Name: Fayyaz
# Date of Birth: 24-6-2010

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Shabbir"
age = "14"
city = "Karachi"
hobby = "Gaming"
father_name = "Fayyaz"
future_goal = "AI Engineer"

# %%
print ("Name: " + name)
print ("Age: " + age)
print ("City: " + city)
print ("Hobby: " + hobby)
print ("Father's Name: " + father_name)
print ("Future Goal: " + future_goal)
# Out:
# Name: Shabbir
# Age: 14
# City: Karachi
# Hobby: Gaming
# Father's Name: Fayyaz
# Future Goal: AI Engineer

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
num1 = 10
num2 = 8

# %%
## Arithmetic Operators
print (num1 + num2) 
print (num1 - num2)
print (num1 * num2)
print (num1 / num2)
print (num1 % num2)
print (num1 ** num2)
print (num1 // num2)
# Out:
# 18
# 2
# 80
# 1.25
# 2
# 100000000
# 1

# %%
#Comparison Operator
print (num1 == 10)
print (num1 != 10)
print (num1 > 10)
print (num1 < 10)
print (num1 >= 10)
print (num1 <= 10)
# Out:
# False
# True
# True
# False
# True
# False

# %%
#Assignment Operators
num1 += num2
print (num1)
num1 -= num2 
print (num1)
num1 *= num2
print (num1)
num1 /= num2
print (num1)
num1 %= num2
print (num1)
num1 **= num2
print (num1)
num1 //= num2
print (num1)
# Out:
# 40.0
# 32.0
# 256.0
# 32.0
# 0.0
# 0.0
# 0.0

# %%
#Logical Operators
print((num1 > num2) and (num1 < 20))
print((num1 > num2) or (num1 < num2))
print(not (num1 == num2))
# Out:
# False
# True
# True

# %% [markdown]
# 4. Completes the following steps of small task: Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables Mention Variable of Total Marks and assign 300 to it Calculate Percentage

# %%
english = 99
islamiat = 100
math = 90
total_marks = 300
obtained_marks = english + islamiat + math
percentage = (obtained_marks / total_marks) * 100
print (f"Total Marks is: {total_marks}")
print (f"Obtained Marks is: {obtained_marks}")
print (f"Percentage is: {percentage}%")
# Out:
# Total Marks is: 300
# Obtained Marks is: 289
# Percentage is: 96.33333333333334%
