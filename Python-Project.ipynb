# %% [markdown]
# 1.🎯Python Project :- Secret Number Guessing Game
# (Objective)
#
# Create a Secret Number Guessing Game using Python.
#
# The program should allow the user to guess a secret number until the correct number is entered

# %%
secret_number = 99
num=int(input("Enter the number to guess the secret number"))
while True: 
    secret_number
    if num < secret_number:
        print("your guess number is too small & can't be matched")
        num=int(input("Enter the number again to guess"))
    elif num > secret_number:
            print("your guess number is too high & can't be matched")
            num=int(input("Enter the number again to guess"))
    elif num == secret_number:
         print("Your guess number is matched succesfully")
         break
# Out:
# Your guess number is matched succesfully

# %% [markdown]
# 2.🛒 Python Project: Mini Shopping Cart System
# Objective
#
# Create a Mini Shopping Cart System using Python.
#
# The program should allow the user to purchase multiple items calculate the total bill and display the final bill at checkout.
#
# Requirements
#
# Create a shopping menu with the following items:-
#
# Option	Item	         Price
# 1	      Apple	           100
# 2	      Mango	           200
# 3	      Pulses	       150
# 4	      Chicken	       300
# 5	      Candies	       10
# 6	      Tomato	       150
# 7	      Potato	       100
# 8	     Lady Finger	   350
# 9	 Coriander & Chilli	   200
# 10	    Checkout,Exit

# %%
total = 0
while True:
    print ("\n=====Welcome to our shop=====")
    print ("1. Apple = 100")
    print ("2.mango = 200 ")
    print ("3.Pulses = 150")
    print ("4.Chicken = 300")
    print ("5.Candies = 10")
    print ("6.tomato = 150")
    print ("7.potato = 100")
    print ("8.ladyfinger = 350")
    print ("9.coriander & chilly = 200")
    print ("10.Checkout")
    user_input=int(input("Enter Your Choice"))
    if user_input == 1:
       print ("\nApple has been succesfully added to you cart ")
       total = total + 100 
       print("your total bill is", total)
    elif user_input == 2:
       print("\nMango has been succesfully added to your cart ")
       total = total + 200
       print("your total bill is",total )
    elif user_input == 3:
       print("\nPulses has been succesfully added to your cart")
       total = total + 150
       print("Your total bill is",total)
    elif user_input == 4:
       print("\nChicken has been succesfully added to your cart")
       total = total + 300
       print("your total bill is", total)   
    elif user_input == 5:
       print("\nCandies has been succesfully added to your cart")
       total = total + 10
       print ("your total bill is", total)
    elif user_input == 6:
       print("\nTomato has been successfully added to your cart")
       total = total + 150
       print("Your total bill is",total)
    elif user_input == 7:
        print("\nPotato has been successfully added to your cart") 
        total = total + 100
        print ("Yout total bill is",total)
    elif user_input == 8:
        print("\nLady finger has been successfully added to your cart")
        total = total +350
        print ("your total bill is", total) 
    elif user_input == 9:
        print("\nCoriander & chilly has been successfully added to your cart")
        total = total + 200
        print ("your total bill is",total)  
    elif user_input == 10:
        print("\n=======FINAL BILL========")
        print("your total bill is", total)
        print("thanks visit again our page")
        break
    else:                 
        print("invalid choice plz try again")
# Out:
# =====Welcome to our shop=====
# 1. Apple = 100
# 2.mango = 200
# 3.Pulses = 150
# 4.Chicken = 300
# 5.Candies = 10
# 6.tomato = 150
# 7.potato = 100
# 8.ladyfinger = 350
# 9.coriander & chilly = 200
# 10.Checkout
#
# Apple has been succesfully added to you cart
# your total bill is 100
#
# =====Welcome to our shop=====
# 1. Apple = 100
# 2.mango = 200
# 3.Pulses = 150
# 4.Chicken = 300
# 5.Candies = 10
# 6.tomato = 150
# 7.potato = 100
# 8.ladyfinger = 350
# 9.coriander & chilly = 200
# 10.Checkout
#
# Potato has been successfully added to your cart
# Yout total bill is 200
#
# =====Welcome to our shop=====
# 1. Apple = 100
# 2.mango = 200
# 3.Pulses = 150
# 4.Chicken = 300
# 5.Candies = 10
# 6.tomato = 150
# 7.potato = 100
# 8.ladyfinger = 350
# 9.coriander & chilly = 200
# 10.Checkout
#
# =======FINAL BILL========
# your total bill is 200
# thanks visit again our page
