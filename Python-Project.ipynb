# %%
secret_number = 99

# %%
num=int(input("Enter the number to guess the secret number"))
while True: 
    secret_number
    if num < secret_number:
        print("your guess number is too small & can't be matched")
        num=int(input("Enter the number again to guess"))
    elif num > secret_number:
            print("your guess number is too high & can't be matched")
            num=int(input("Enter the number again to guess"))
    elif num == secret_number:
         print("Your guess number is matched succesfully")
         break
# Out:
# your guess number is too small & can't be matched
# your guess number is too high & can't be matched
# Your guess number is matched succesfully

# %%
apple = 100 
Mango = 200
grapes = 150 
chicken = 250
pulses = 50 
candies = 10

# %%
Total = 0
while True:
    print ("Welcome to our shop")
    print ("1. Apple = 100")
    print ("2.mango = 200 ")
    print ("3.Pulses = 150")
    print ("4.Chicken = 300")
    print ("5.Candies = 10")
    print ("6.tomato = 150")
    print ("7.potato = 100")
    print ("8.ladyfinger = 350")
    print ("9.coriander & chilly = 200")
    print ("10.Checkout")
    user_input=int(input("Enter Your Choice"))
    if user_input == 1:
     print ("Apple has succesfully added to you cart ")
    total = total + 100 
    print("your total bill is", total)
    if user_input == 2:
       print("Mango has succesfully added to your cart ")
    total = total + 200
    print("your total bill is",total )
    if user_input == 3:
       print("Pulses has succesfully added to your cart")
       total = total + 150
    print("Your total bill is",total)
    if user_input == 4:
       print("Chicken has succesfully added to your cart")
       total = total + 300
    print("your total bill is", total)   
    if user_input == 5:
       print("Candies has succesfully added to your cart")
       total = total + 10
    print ("your total bill is", total)
       if user_input == 6:
          print("Tomato has successfully added to your cart")
          total = total + 150
# Out:
# Welcome to our shop
# 1. Apple = 100
# 2.mango = 200
# 3 Pulses = 150
# 4 Chicken = 300
# 5 checkout
# Apple has succesfully added to you cart
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 12
#       8     print ("5 checkout")
#       9     user_input=int(input("Enter Your Choice"))
#      10     if user_input == 1:
#      11      print ("Apple has succesfully added to you cart ")
# ---> 12     total = total + 100
#      13     print("your total bill is", total)
#
# NameError: name 'total' is not defined
